# %%
class MiClase():
  def __init__(self):
    self.y=2

  def operar(self, x):
    return x * self.y

# %%
n = MiClase()
n.operar(2)
# Out:
# 4

# %%
import torch
import torch.nn as nn
import torch.optim as optim
#import pdb

wh = torch.Tensor( [2.0,-3.0,-3.0]) # , requires_grad=True)
#wh.requires_grad_(True)
x = torch.Tensor( [-1.0, -2.0] )
xx = torch.Tensor( [-1.0, -2.0, 1.0] )
t = torch.Tensor( [0.5] )
M = torch.Tensor()

class Perceptron( nn.Module ):
  def __init__( self):   #, weights ):
    super( Perceptron, self ).__init__()
    self.layer = nn.Linear( 2, 1 )
#    with torch.no_grad():
#      self.layer.weight.copy_( weights[:2] )
#      self.layer.bias.copy_( weights[2] )
    self.sigmoid = nn.Sigmoid()
  def forward( self, x ):
    x = self.sigmoid( self.layer(x) )
    return x

def my_hook(grad):
  print('>>',grad)
  return grad

#wh.register_hook(my_hook)
#wh.register_hook(lambda grad:print(grad))
#wh.retain_grad()

#register_full_backward_hook 
def my_hook_bg(module, input, output):
  print(input, output)
  return input

model = Perceptron( ) #wh
#model.register_backward_hook(my_hook_bg)
##model.register_full_backward_hook(my_hook_bg)

mse_loss = nn.MSELoss()
optimizer = optim.SGD( model.parameters(), lr = 0.01 ) # Learning rate equal to 0.01

pr = model( x )          # forward step
loss_value = mse_loss( pr, t )
print( 'First output value: %.4f' % (pr) )
while loss_value.item() > 1e-4:
  #pdb.set_trace()
  print('X y W =>>> ', x, wh)
  M = torch.matmul(xx,wh)
  print('X x W =>> ', M)
  loss_value.backward() # backward step
  #pdb.set_trace()
  optimizer.step()      # weights update
  pr = model( x )        # forward step
  loss_value = mse_loss( pr, t )
  print( 'current loss: %.4f  pr:%.4f - target:%.4f' % (loss_value.item() , pr, t))
  print('\n')
print( 'Last output value: %.4f' % (pr) )
# Out:
# First output value: 0.0878
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1697  pr:0.0881 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1692  pr:0.0887 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1684  pr:0.0897 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1673  pr:0.0910 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1659  pr:0.0927 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1643  pr:0.0947 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1623  pr:0.0972 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1600  pr:0.1001 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1573  pr:0.1034 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1542  pr:0.1073 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1507  pr:0.1118 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1468  pr:0.1169 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1424  pr:0.1227 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1374  pr:0.1293 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1319  pr:0.1368 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1258  pr:0.1453 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1191  pr:0.1549 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1117  pr:0.1658 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1036  pr:0.1781 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0949  pr:0.1920 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0855  pr:0.2076 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0755  pr:0.2252 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0651  pr:0.2448 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0544  pr:0.2667 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0437  pr:0.2909 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0333  pr:0.3175 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0236  pr:0.3464 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0150  pr:0.3774 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0080  pr:0.4104 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0030  pr:0.4448 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0004  pr:0.4801 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0003  pr:0.5158 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0026  pr:0.5513 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0074  pr:0.5858 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0141  pr:0.6189 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0226  pr:0.6502 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0322  pr:0.6794 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0425  pr:0.7062 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0532  pr:0.7307 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0639  pr:0.7528 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0744  pr:0.7727 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0844  pr:0.7905 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.0938  pr:0.8063 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1027  pr:0.8204 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1108  pr:0.8329 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1183  pr:0.8439 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1251  pr:0.8537 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.1313  pr:0.8623 - target:0.5000
#
#
# X y W =>>>  tensor([-1., -2.]) tensor([ 2., -3., -3.])
# X x W =>>  tensor(1.)
# current loss: 0.